# %% [markdown]
# # AURA Google Colab GPU & Benchmark Validation Suite
#
# Run this notebook in Google Colab with T4 / A100 GPU acceleration enabled to benchmark AURA across Linux cgroup v2, CUDA GPU offloading, and multi-tier model performance.

# %%
# Step 1: Clone AURA and run automated Colab environment setup
# !git clone https://github.com/Grevix/aura.git aura_colab
# %cd aura_colab
# !bash benchmarks/colab/setup_colab.sh

# %%
# Step 2: Run AURA Doctor and GPU Doctor
# !./target/release/aura doctor
# !./target/release/aura gpu-doctor

# %%
# Step 3: Run GPU Benchmark Suite and Collect Telemetry
# !python3 benchmarks/colab/run_gpu_benchmark.py
