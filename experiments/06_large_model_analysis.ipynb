# %% [markdown]
# # AURA Experiment Lab: 06 — Large Model Scaling

# %%
import subprocess
res = subprocess.run(['cargo', 'run', '-p', 'aura-cli', '--', 'plan', '-m', 'gemma4:latest', '-b', '8G'], capture_output=True, text=True)
print(res.stdout)
