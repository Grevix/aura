# %% [markdown]
# # AURA Experiment Lab: 00 — Environment Diagnostics

# %%
import subprocess
import json

# Run AURA hardware telemetry probe
res = subprocess.run(['cargo', 'run', '-p', 'aura-cli', '--', 'doctor'], capture_output=True, text=True)
print(res.stdout)

# %%
# Inspect local environment software versions
# !rustc --version
# !cargo --version
# !python --version
# !ollama --version
