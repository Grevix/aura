# %% [markdown]
# # AURA Experiment Lab: 04 — Memory Pressure Telemetry

# %%
import subprocess
res = subprocess.run(['cargo', 'run', '-p', 'aura-cli', '--', 'run', '-m', 'qwen2.5-coder:7b', '-b', '4G', '-p', 'Test memory pressure'], capture_output=True, text=True)
print(res.stdout)
