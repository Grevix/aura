# %% [markdown]
# # AURA Experiment Lab: 07 — GLM-5.2 Cloud Reference Analysis
#
# GLM-5.2 parameters: ~744B in BF16 (~1.5 TB storage footprint). Serves as cloud reference baseline.
