# %% [markdown]
# # AURA Experiment Lab: 10 — Final Synthesis & Telemetry Database

# %%
import subprocess
res = subprocess.run(['cargo', 'run', '-p', 'aura-cli', '--', 'audit', '-o', 'audit.json'], capture_output=True, text=True)
print(res.stdout)
